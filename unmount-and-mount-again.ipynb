# %%
dbutils.fs.mounts()

# %%
dbutils.fs.unmount('/mnt/layers/14533/changelet')
dbutils.fs.unmount('/mnt/layers/14533/snapshot')

## while running LoadSnapshot, both paths will be mounted again

# %%
dbutils.fs.mount(
  source = "wasbs://rp-generation-prod@addressrangesduplicate.blob.core.windows.net",
  mount_point = "/mnt/aqua",
  extra_configs = {
    "fs.azure.account.key.<storage-account-name>.blob.core.windows.net": "<storage-account-key>"
  }
)
